# %%
from bs4 import BeautifulSoup

# %%
with open("./htmlfiles/Abandoned vehicles and goods.html") as fp:
    soup = BeautifulSoup(fp, 'html.parser')

# %%
pip install html2text
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
soup.body
# Out:
# <body class="" data-gr-ext-installed="" data-new-gr-c-s-check-loaded="14.1149.0"><div id="__nuxt"><div class="bg-ui-offwhite" id="app"><!-- --><div id="layout__default"><div id="global-notification"><div class="Alert py-3 border-solid border shadow-md bg-blue-100 border-blue-400"><div class="container mx-auto px-4 md:px-6 lg:px-8 flex flex-col items-center md:flex-row md:justify-between"><!--[--><div class="flex items-center is-title-4"><svg aria-hidden="true" class="svg-inline--fa fa-circle-info fa-fw fa-xs Alert__Icon mr-1" data-icon="circle-info" data-prefix="fal" focusable="false" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><path class="" d="M256 32a224 224 0 1 1 0 448 224 224 0 1 1 0-448zm0 480A256 256 0 1 0 256 0a256 256 0 1 0 0 512zM208 352c-8.8 0-16 7.2-16 16s7.2 16 16 16h96c8.8 0 16-7.2 16-16s-7.2-16-16-16H272V240c0-8.8-7.2-16-16-16H216c-8.8 0-16 7.2-16 16s7.2 16 16 16h24v96H208zm48-168a24 24 0 1 0 0-48 24 24 0 1 0 0 48z" fill="currentColor"></path></
# ...

# %%
import html2text

def convert_to_markdown(soup):
    """
    Convert BeautifulSoup object to Markdown.

    Parameters:
    soup (BeautifulSoup): The BeautifulSoup object containing HTML content.

    Returns:
    str: The converted Markdown text.
    """
    html_converter = html2text.HTML2Text()
    html_converter.ignore_links = False
    html_converter.bypass_tables = False
    # Convert the HTML to Markdown
    markdown_text = html_converter.handle(str(soup))
    return markdown_text

# %%
x=convert_to_markdown(soup.body)

# %%
file_path = 'output.md'  # You can change the file name and path as needed

# Write the markdown text to the file
with open(file_path, 'w', encoding='utf-8') as file:
    file.write(x)

# %%
from langchain.text_splitter import MarkdownHeaderTextSplitter, MarkdownTextSplitter

# %%
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3")
]

# %%
markdown_splitter = MarkdownHeaderTextSplitter(
    headers_to_split_on=headers_to_split_on,
    # strip_headers=False
)
md_header_splits = markdown_splitter.split_text(x)

# %%
md_header_splits
# Out:
# [Document(page_content='Half yearly rate notices will be issued on 23 January 2024, with a due date of\n23 February 2024. View previous notices in MyCouncil.  \n[Read more](https://www.sunshinecoast.qld.gov.au/pay-and-apply/rates "Half\nyearly rate notices will be issued on 23 January 2024, with a due date of 23\nFebruary 2024. View previous notices in MyCouncil.")  \nOur sites`[production] 1.3.2.1116`  \nAccessibility  \n[Help & Support](https://www.sunshinecoast.qld.gov.au/council/contact-\ncouncil/site-help "Help & Support")[Contact\nCouncil](https://www.sunshinecoast.qld.gov.au/council/contact-council "Contact\nCouncil")[MyCouncil](https://mycouncil.sunshinecoast.qld.gov.au/ "MyCouncil\nApp")  \nMenu  \n[](https://www.sunshinecoast.qld.gov.au/ "Corporate homepage")  \nExperience Sunshine CoastLiving and\ncommunityEnvironmentBusinessDevelopmentCouncilPay and apply  \nI want to ...  \nSearch website  \n[Rates\ninformation](https://www.sunshinecoast.qld.gov.au/direct/cdbd895c-b2da-5
# ...

# %%
# Assuming your initial content and metadata are as follows:
page_content = md_header_splits[6].page_content
metadata = md_header_splits[6].metadata

# Function to append metadata headers to the page content in hierarchical order
def append_headers_to_content(content, headers):
    # Sort the keys in descending order to ensure headers are added in hierarchical order
    sorted_keys = sorted(headers.keys(), key=lambda x: int(x.split()[-1]), reverse=True)
    print(sorted_keys)
    for key in sorted_keys:
        value = headers[key]
        # Determine the header level based on the key
        header_level = key.split()[-1]  # Extract the number from the header key
        header_markdown = '#' * int(header_level)  # Convert number to markdown header level

        # Append the header to the content
        content = f"{header_markdown} {value} \n"+content
    return content

# Append the headers to the page content
page_content = append_headers_to_content(page_content, metadata)

print(page_content)
# Out:
# ['Header 3', 'Header 2', 'Header 1']
# # Abandoned vehicles and goods
# ## Collecting impounded vehicles or goods
# ### Abandoned vehicle auctions
# Sunshine Coast Council abandoned vehicles auctions are run on a regular basis
# for all abandoned vehicles and unclaimed impounded items.
# The last auction was Saturday 11 November 2023
# #### Terms and conditions
# * Full payment is required on the day of the auction (EFTPOS accepted).
# * Items are sold 'as is'.
# * Council reserves the right to withdraw any vehicle advertised before the auction.
# Sunshine Coast Council acknowledges the Sunshine Coast Country, home of the
# Kabi Kabi peoples and the Jinibara peoples, the Traditional Custodians, whose
# lands and waters we all now share.
# We commit to working in partnership with the Traditional Custodians and the
# broader First Nations (Aboriginal and Torres Strait Islander) community to
# support self-determination through economic and community development.
# ...

# %% [markdown]
# <button type="button" class="btn btn-primary mt-1 ml-3 sticky-top" onclick="window.location.reload();">New Topic</button>
